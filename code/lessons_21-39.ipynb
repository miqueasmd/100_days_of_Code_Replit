# %% [markdown]
# # Day 21 Challenge
#
# Test your family and friends on their multiplication knowledge (or just be really mean to people you know and ask them to work out their multiplication tables for 5,474,000,000....)
#
# 1. Prompt the user by asking for a multiplication table for the number of their choice.
# 2. Generate the multiplication table for 1 to 10 times that number and ask each math fact as a question (psst...that's a hint).
# 3. If the user gets the math correct, award them a point. If they get it wrong, do not give them any points.
# 4. At the end of the 10 rounds, show the user their score out of 10 for how many math facts they got correct.
# 5. Why not give users an emoji if they get all 10 math facts correct?
#
# ## Math Game!
#
# **Name your multiples:** 7
# ```
# 1 X 7 = 7
# Great work!
# 2 X 7 = 14
# Awesome!
# 3 X 7 = 54
# Nope. The answer was 21.
# ---
# You scored 3 out of 10.
# ```
# ### Instructions
# 1. Use a variable when asking the user what multiplication facts they want to solve.
# 2. Within the for loop, set up a variable, input statement, and if statements.
# 3. Don't forget to include your counter and an if statement to say when to give a perfect score emoji.

# %%
print("Welcome to Math Facts Game")
print()
print("How well do you know your math facts? Pick a number and I will give you 10 math facts to solve.")
print()

# Prompt user for the multiplication table number
try:
    fact_family = int(input("Name your multiples: "))
except ValueError:
    print("Please enter a valid number.")
    exit()

print()

# Initialize the score counter
counter = 0

# Loop through 1 to 10 to generate multiplication questions
for i in range(1, 11):
    correct_answer = i * fact_family
    print(i, "x", fact_family)
    
    try:
        answer = int(input("> "))
    except ValueError:
        print("Invalid input. Please enter a number.")
        continue
    
    if answer == correct_answer:
        print("You got it right!")
        counter += 1
    else:
        print("That's not correct. It should have been", correct_answer)

# Display the final score
if counter == 10:
    print("Wow! A perfect score! 🥳")
else:
    print("You got", counter, "out of 10 correct.")

# %% [markdown]
# # Day 22 Challenge
#
# Copy and paste your code from Day 18.
#
# We are going to make a change to this project:
#
# 1. Make the number generator completely random between 1 and 1,000,000.
# 2. Now, the game will always have the user guess a random number each time (now the user can't cheat...)
#
# ## Totally Random One-Million-to-One
#
# ```
# Totally Random One-Million-to-One
#
# What is your guess?: 500000
# Too low
#
# What is your guess?: 750000
# Too high
#
# What is your guess?: 600000
# Too low
#
# What is your guess?: 650000
# Correct!
#
# It took you 4 guesses to get the number correct.
# Click 'run' to try again with a different number.
# ```
# ### Instructions
# 1. Remember to import your library first and do NOT add it in the loop.
# 2. You can keep a lot of Day 18's code, but need to add the random library.

# %%
import random

print("Welcome to Guess the Number.")
print()
print("Guess a number between 1 and 1000000 and I will tell you if you are too low, too high, or get it correct.")
print()
print("Let's play!")


attempt = 0
myNumber = random.randint(1,1000000)

while True: 
  user_guess = int(input("Pick a number between 1 and 1,000,000: "))
  if user_guess < myNumber:
    print("That number is too low. Try again!")
    attempt += 1
  elif user_guess > myNumber:
    print("That number is too high. Try again!")
    attempt += 1
    continue
  elif user_guess == myNumber:
    print("You are a winner! 🥳🥳")
    break 
    exit()
  else:
    print("That is not a number I recognize.")
print("It took you", attempt, "attempt(s) to get the correct answer.")

# %% [markdown]
# # Day 23 Challenge
#
# 1. Create a subroutine with both a username and password.
# 2. Create a loop to prompt the user again and again until they put in the correct login information.
#
# ## Replit Login System
# ```
# Replit Login System
#
# What is your username?: david
# What is your password? whatAmazingHairYouHave
#
# Whoops! I don't recognize that username or password. Try again!
#
# What is your username? david
# What is your password? baldies4life
#
# Welcome to Replit!
# ```
#
# ### Instructions
# 1. Create one login subroutine. Maybe you should call it `login`.
# 2. Use `input` and `if` statements inside a loop.
# 3. Determine where the loop needs to break and where it needs to continue.

# %%
def login():
  while True:
    username = input("What is your username?: ")
    password = input("What is your password? ")
    if username == "David" and password == "Replit4ev#r":
      print("Welcome David!")
      break
    else:
      print("That is not the correct username or password. Try again!")
      continue
    
print("REPLIT LOGIN SYSTEM")
login()

# %% [markdown]
# # Day 24 Challenge
#
# Let's build an infinity dice!
#
# 1. Create subroutines that will roll a dice with any number of sides (essentially as big of a number as you like).
# 2. Write one subroutine with one parameter that allows us to call a function (such as `rollDice`).
#
# ## Example
# ```
# Infinity Dice 🎲
#
# How many sides?: 600
# You rolled 532
#
# Roll again? yes
# You rolled 102
#
# Roll again? no
# ```
#
# ### Instructions
# 1. Import your library first.
# 2. Create a variable to ask the user how many sides the dice should be.
# 3. Create a variable that allows the user to leave the game.
# 4. Create a subroutine with `rollDice` that sets the sides of the dice as the argument.
# 5. Create a while loop that allows the user to roll again or leave the game.

# %%
import random
print("Infinity Dice 🎲")
  
sides = int(input("How many sides?: "))
playGame = "yes"
  
def rollDice(sides):
  print("You rolled ", random.randint(1,sides))
while playGame == "yes":
    rollDice(sides)
    playGame = input("Roll again?")

# %% [markdown]
# # Day 25 Challenge
#
# Let's extend Day 24's project and create a health stats generator for a character in a video game.
#
# 1. Create a subroutine that rolls a dice of any size and returns that number.
# 2. Then, create a second subroutine that rolls one six-sided dice and one eight-sided dice.
# 3. Multiply the number from the six-sided dice and eight-sided dice together and return that subroutine as a character's health stats for a video game.
# 4. Print out the character's health stats.
# 5. Add a loop to give the user the option to generate health stats for another character.
# (We genuinely see this in video games!)
#
# 🥳 Extra points if you ask for the character's name and double extra points if you use different colors!
#
# ## ⚔️ Character Stats Generator ⚔️
# ```
# Name your warrior: Agnes
# Their health is: 20hp
#
# Name your warrior: Ian
# Their health is: 6hp
#
# Name your warrior: Penelope
# Their health is: 48hp
# ```
#
# ### Instructions
# 1. Import your library first.
# 2. Create one subroutine for a dice of any number and return it.
# 3. Create a subroutine that rolls a dice with numbers 1-6 and a dice with numbers 1-8 and multiplies the two numbers together. Return that subroutine.
# 4. Ask the user to name their character and print that character's health stats.
# 5. Create a while loop to allow the user to generate a new character's health stats.

# %%
import random

def rollDice(sides):
  result = random.randint(1,sides)
  return result

def roll_6_and_8():
  roll_6_sided_dice = rollDice(6)
  roll_8_sided_dice = rollDice(8)
  health = roll_6_sided_dice * roll_8_sided_dice
  return health

print("⚔️Character stats generator⚔️")
  

haveACharacter = "yes"

while haveACharacter == "yes":
  character = input("Name your warrior: ")
  health = str(roll_6_and_8())
  print("Their health is ", health,"hp" ) 
  haveACharacter = input("Want to create another character?")

# %% [markdown]
# # Day 26 Challenge
#
# Play a song from this repl and build a menu to go with it. Make it look like an iPod!
#
# When you run the code below, it should open the Output tool which will have a checkbox with a headphones icon in the bottom right corner. Select this checkbox to hear the sound. (It may be behind the video.)
#
# ## Instructions
# 1. Use a `while True` loop to create a title for a music player.
# 2. Allow the user to select to play a song and use a subroutine called `play` when they select the song.
# 3. Give the user the option to exit the program.
# 4. The title should pop up and pause along with the menu options.
# 5. If the user chooses anything else, start again by clearing the screen.
#
#
# ### Code
# ```python
# import os
# import time
# import pygame
#
# # Initialize pygame mixer
# pygame.init()
# pygame.mixer.init()
#
# # Load the sound
# sound = pygame.mixer.Sound('audio.wav')
#
# def pause():
#     pygame.mixer.pause()
#
# def play():
#     # Play the sound
#     pygame.mixer.unpause()
#     while True:
#         # Start taking user input and doing something with it
#         input()
#
# while True:
#     # Clear the screen
#     os.system('cls' if os.name == 'nt' else 'clear')
#
#     # Show the menu
#     print("🎵 MyPOD Music Player")
#     print("Press 1 to Play")
#     print("Press 2 to Exit")
#     print("Press anything else to see the menu again.")
#
#     # Take user's input
#     choice = input("Enter your choice: ")
#
#     # Check whether you should call the play() subroutine depending on user's input
#     if choice == '1':
#         play()
#     elif choice == '2':
#         break
#     else:
#         continue
# ```
#
# ## Example
# ```
# 🎵 MyPOD Music Player
#
# Press 1 to Play
# Press 2 to Exit
#
# Press anything else to see the menu again.
# ```
#
# # Notes
# 1. Import your libraries first.
# 2. With the sample code above, think about what code can be added to pause and play the audio.
# 3. What command do you need to use to return (hint, hint) to the main menu (subroutine)?
# 4. Create a while True loop that clears the code and pauses the code. What libraries would you need for these things to happen?
# 5. You may also need if statements within your loop.

# %%
import os
from dotenv import load_dotenv  # Add this import
import time
import pygame

# %%
# Load environment variables
load_dotenv()

# Initialize pygame mixer
pygame.init()
pygame.mixer.init()

# Load the sound
base_path = os.getenv('BASE_PATH', '.')  # Default to current directory if BASE_PATH is not set
audio_path = os.path.join(base_path, 'data/pimo_alon.mp3')
sound = pygame.mixer.Sound(audio_path)
sound.play()
pygame.mixer.pause()

def pause():
    pygame.mixer.pause()

def play():
    # Play the sound
    pygame.mixer.unpause()
    while True:
        try:
            stop_playback = int(input("Press 2 anytime to pause playback and go back to the menu: "))
            if stop_playback == 2:
                pause()
                break  # Break out of the loop to return to the main menu
        except ValueError:
            print("Invalid input. Please enter a number.")

while True:
    os.system('cls' if os.name == 'nt' else 'clear')
    print("🎵 MyPOD Music Player ")
    time.sleep(1)
    print("Press 1 to Play")
    print("Press 2 to Exit")
    print("Press anything else to see the menu again")
    
    try:
        userInput = int(input("Enter your choice: "))
        if userInput == 1:
            print("Playing some proper tunes!")
            play()
        elif userInput == 2:
            break  # Exit the main loop to end the program
        else:
            continue
    except ValueError:
        print("Invalid input. Please enter a number.")

# %% [markdown]
# # Day 27 Challenge
#
# Welcome to your first video game creation. You will create a video game that creates a character's health and attack stats...along with an epic name for your character.
#
# Do not delete today's code. You will be building upon it on Day 28.
#
# ## Instructions
# 1. Write a subroutine that generates a character: first name and character type (human, imp, wizard, elf, etc.).
# 2. Write a subroutine that multiplies a bunch of random dice rolls together to generate the character's health stats. Use this formula:
# 3. Write a second subroutine that multiplies a bunch of random dice rolls together to generate the character's strength stats. Use this formula:
# 4. Present the data in a menu with `time.sleep` and `os.system("clear")` to make it appealing.
# 5. Wrap it in a loop so the user has the option to create another character.
#
# ## Example
# ```
# Character Builder
#
# Name Your Legend:
# Sheila the Almighty
#
# Character Type (Human, Elf, Wiard, Orc):
# Human
#
# Sheila the Almighty
# HEALTH: 40
# STRENGTH: 26
#
# May your name go down in Legend...
# ```
#
# ### Instructions
# 1. Import libraries first. You will need to use all three libraries you have learned so far.
# 2. You will need four subroutines: character name and type, to create a random sided dice, for the formula to generate health, and for the formula to generate strength. You will return each subroutine.
# 3. Create a while loop that allows the player to choose to play again, clears the code, and pauses it when needed (think about your libraries).

# %%
import random, os, time

def rollDice(side):
  result = random.randint(1,side)
  return result

def health():
  healthStat = ((rollDice(6)*rollDice(12))/2)+10
  return healthStat

def strength():
  strengthStat = ((rollDice(6)*rollDice(8))/2)+12
  return strengthStat

while True:
    print("⚔️ CHARACTER BUILDER ⚔️")
    print()
    
    # Ensure the user provides a name
    while True:
        name = input("Name your Legend:\n")
        if name.strip():
            break
        print("Name cannot be empty. Please enter a valid name.")
    
    character_type = input("Character Type (Human, Elf, Wizard, Orc):\n")
    print()
    print(f"{name} the {character_type}")
    print("HEALTH:", health())
    print("STRENGTH:", strength())
    print()
    print("May your name go down in Legend…")
    print()
    
    again = input("Again? (yes/no):\n")
    if again.lower() == "no":
        break
    
    time.sleep(1)
    os.system('cls' if os.name == 'nt' else 'clear')

# %%
#Handling ESC Key

# Import required libraries
import random, os, time
from pynput import keyboard  # Library for keyboard event handling
import sys  # For system-related operations

# Global variable to track if user wants to exit
should_exit = False

def on_press(key):
    """Callback function that runs every time a key is pressed"""
    global should_exit  # Access the global variable
    try:
        if key == keyboard.Key.esc:  # Check if ESC key was pressed
            print("\nExiting game...")
            should_exit = True  # Set flag to exit game
    except:
        pass  # Ignore any errors from key processing

# Create and start keyboard listener in background
listener = keyboard.Listener(on_press=on_press)
listener.start()

# Game mechanics functions
def rollDice(side):
    """Generate random number between 1 and specified sides"""
    result = random.randint(1,side)
    return result

def health():
    """Calculate character health using dice rolls"""
    healthStat = ((rollDice(6)*rollDice(12))/2)+10
    return healthStat

def strength():
    """Calculate character strength using dice rolls"""
    strengthStat = ((rollDice(6)*rollDice(8))/2)+12
    return strengthStat

print("Press ESC at any time to exit")

# Main game loop
while not should_exit:  # Continue until ESC is pressed
    print("⚔️ CHARACTER BUILDER ⚔️")
    print()
    
    # Name input loop - continues until valid name or ESC
    while not should_exit:
        name = input("Name your Legend:\n")
        if name.strip():  # Check if name isn't just whitespace
            break
        print("Name cannot be empty. Please enter a valid name.")
    
    # Exit check after name input
    if should_exit:
        break
        
    # Get character type
    character_type = input("Character Type (Human, Elf, Wizard, Orc):\n")
    print()
    
    # Display character stats
    print(f"{name} the {character_type}")
    print("HEALTH:", health())
    print("STRENGTH:", strength())
    print()
    print("May your name go down in Legend…")
    print()
    
    # Ask to play again
    again = input("Again? (yes/no):\n").lower()
    if again == "no" or should_exit:  # Exit if 'no' or ESC pressed
        break
    
    # Clear screen and pause briefly between games
    time.sleep(1)
    os.system('cls' if os.name == 'nt' else 'clear')  # Clear screen (works on Windows and Unix)

# Clean up keyboard listener when game ends
listener.stop()

# %% [markdown]
# # Day 28 Challenge
#
# Use Day 27's character generator for this project...to build an automated game battle system!
#
# ## Instructions
# 1. Add return functions to your character's health and strength statuses from Day 27's project.
# 2. Generate two different characters and store their data (health and strength stats, character type, name, etc.).
# 3. Use a `while True` loop to simulate those two characters battling.
# 4. Roll one six-sided dice for both characters. The character who rolls the higher amount wins that round.
# 5. The winner of that round (the one who rolled the higher number) will give damage to the other character by doing the following:
#    - Find the difference between the strength of both opponents and add one.
#    - Take that amount away from the loser's health.
# 6. At the end of each round, check the stats of each character to ensure neither of them have died yet.
# 7. When one character dies (they run out of health), declare a winner of the battle!
# 8. To keep this battle from looking hideous between rounds use `time.sleep` to pause between rounds and `os.system("clear")` to ensure the screen clears between battles.
# 9. Extra points for the use of emojis, colors, or even sound code!
#
# ## Example
# ```
# ⚔️ BATTLE TIME ⚔️
#
# Name your Legend:
# Arthur the Magnificent
# Character Type (Human, Elf, Wizard, Orc):
# Elf
#
# Arthur the Magnificent
# HEALTH: 13
# STRENGTH: 18
#
# Who are they battling?
#
# Name your Legend:
# Sheila the Almighty
# Character Type (Human, Elf, Wizard, Orc):
# Human
#
# Sheila the Almighty
# HEALTH: 40
# STRENGTH: 26
#
# *clear screen here*
#
# ⚔️ BATTLE TIME ⚔️
#
# The battle begins!
#
# Arthur wins the first blow
# Sheila takes a hit, with 8 damage
#
# Arthur the Magnificent
# HEALTH: 13
#
# Sheila the Almighty
# HEALTH: 32
#
# And they're both standing for the next round!
#
# *clear screen here*
#
# ⚔️ BATTLE TIME ⚔️
#
# The battle continues!
#
# Sheila wins round 2
# Arthur takes a hit, with 8 damage
#
# Arthur the Magnificent
# HEALTH: 5
#
# Sheila the Almighty
# HEALTH: 32
#
# And they're both standing for the next round!
#
# *clear screen here*
#
# ⚔️ BATTLE TIME ⚔️
#
# The battle continues!
#
# Sheila wins round 3
# Arthur takes a hit, with 8 damage
#
# Arthur the Magnificent
# HEALTH: -3
#
# Sheila the Almighty
# HEALTH: 32
#
# Oh no Arthur the Mighty has died!
#
# Sheila the Almighty destroyed Arthur the Magnificent in 3 rounds!
# ```
#
# ## Steps
# 1. Start with the code you created from Day 27.
# 2. Keep the same subroutines as Day 27 and add one more subroutine about character damage (how a winner is declared in each round).
# 3. Tweak the `while` loop from Day 27 to introduce the first character and their stats followed by the character they will battle and that character's stats. (You will want to include pausing and clearing of the code as you did on Day 27).
# 4. Create a counter (within the loop) to keep track of the winner for each round.
# 5. Create another `while` loop inside the current `while` loop with `if` statements, pausing, and clearing of code to show what happens if character 1 wins, the characters tie, etc.
# 6. Make sure you give a recap of the health each character has left after each round.

# %%
import random
import os
import time

def rollDice(side):
    result = random.randint(1, side)
    return result

def health():
    healthStat = ((rollDice(6) * rollDice(12)) / 2) + 10
    return healthStat

def strength():
    strengthStat = ((rollDice(6) * rollDice(8)) / 2) + 12
    return strengthStat

def create_character():
    while True:
        name = input("Name your Legend:\n")
        if name.strip():
            break
        print("Name cannot be empty. Please enter a valid name.")
    
    character_type = input("Character Type (Human, Elf, Wizard, Orc):\n")
    health_stat = health()
    strength_stat = strength()
    
    return {
        "name": name,
        "type": character_type,
        "health": health_stat,
        "strength": strength_stat
    }

def battle(character1, character2):
    round_counter = 0
    while character1["health"] > 0 and character2["health"] > 0:
        os.system('cls' if os.name == 'nt' else 'clear')
        print("⚔️ BATTLE TIME ⚔️")
        print()
        print("The battle begins!")
        
        roll1 = rollDice(6)
        roll2 = rollDice(6)
        
        if roll1 > roll2:
            winner = character1
            loser = character2
        elif roll2 > roll1:
            winner = character2
            loser = character1
        else:
            print(f"Their swords clash and they draw round {round_counter + 1}")
            print()
            print(f"{character1['name']}")
            print(f"HEALTH: {character1['health']}")
            print()
            print(f"{character2['name']}")
            print(f"HEALTH: {character2['health']}")
            print()
            print("And they're both standing for the next round")
            time.sleep(2)
            continue
        
        damage = abs(winner["strength"] - loser["strength"]) + 1
        loser["health"] -= damage
        
        round_counter += 1
        print(f"{winner['name']} wins round {round_counter}")
        print()
        print(f"{character1['name']}")
        print(f"HEALTH: {character1['health']}")
        print()
        print(f"{character2['name']}")
        print(f"HEALTH: {character2['health']}")
        print()
        print("And they're both standing for the next round")
        time.sleep(2)
    
    os.system('cls' if os.name == 'nt' else 'clear')
    print("⚔️ BATTLE TIME ⚔️")
    print()
    if character1["health"] <= 0:
        print(f"{character1['name']} has died!")
        print(f"{character2['name']} has won in {round_counter} rounds")
    else:
        print(f"{character2['name']} has died!")
        print(f"{character1['name']} has won in {round_counter} rounds")

while True:
    print("⚔️ CHARACTER BUILDER ⚔️")
    print()
    
    print("Who is the first character?")
    character1 = create_character()
    
    print()
    print("Who are they battling?")
    character2 = create_character()
    
    battle(character1, character2)
    
    again = input("Again? (yes/no):\n")
    if again.lower() == "no":
        break
    
    time.sleep(1)
    os.system('cls' if os.name == 'nt' else 'clear')

# %% [markdown]
# Add a new line, tab, or vertical tab

# %%
#new line
for i in range(0, 100):
  print(i, end="\n")

# %%
#tab indent
for i in range(0, 100):
  print(i, end="\t")

# %%
#vertical tab
for i in range(0, 100):
  print(i, end="\v")

# %% [markdown]
# Color Changing with end...

# %%
print("If you put")
print("\033[33m", end="") #yellow
print("nothing as the")
print("\033[35m", end="") #purple
print("end character")
print("\033[32m", end="") #green
print("then you don't")
print("\033[0m", end="") #default
print("get odd gaps")

# %% [markdown]
# Let's concatenate that same print statement:

# %%
print("If you put", "\033[33m", "nothing as the", "\033[35m", "end character", "\033[32m", "then you don't", "\033[0m", "get odd gaps", end="")

# %% [markdown]
# Color changing with sep...

# %%
print("If you put ", "\033[33m", "nothing as the ", "\033[35m", "end character ", "\033[32m", "then you don't ", "\033[0m", "get odd gaps ", sep="")

# %% [markdown]
# Counter

# %%
import os, time

for i in range(1, 101):
  print(i)
  time.sleep(0.5)
  os.system("clear")

# %% [markdown]
# # Day 29 Challenge
#
# Write a subroutine that writes text in color. All it will do is print out the text in that color and turn the color back to normal when it's finished.
#
# Control `end` and `sep` so there are no random symbols or spaces.
#
# Check out this [GitHub resource](https://github.com/termcolor/termcolor) for the color codes.
#
#
#
# Create a subroutine with a variable for 'word' and 'color' through the use of if statements. Here is an example of how to include the color red:
# ```python
# if color == "red":
#     print("\033[31m", word, sep="", end="")
# ```
#
# # Instructions:
# 1. print your title 'Super Subroutine' and 'with my' as regular print statements.
# 2. print the rest of the text in different colors by calling the subroutine.

# %%
def newPrint(color, word):
  if color=="red":
    print("\033[31m", word, sep="", end="")
  elif color=="green":
    print("\033[32m", word, sep="", end="")
  elif color=="blue":
    print("\033[34m", word, sep="", end="")
  else:
    print("\033[0m", word, sep="", end="")

print("Super Subroutine")
print("With my ", end="")
newPrint("red", "new program")
newPrint("reset", " I can just call red('and') ")
newPrint("red", "it will print in red ")
newPrint("blue", "or even blue")

# %% [markdown]
# Alignment

# %%
for i in range(1, 31):
  print(f"Day {i} of 30")

# %%
#Better alignment

for i in range(1, 31):
  print(f"Day {i: <2} of 30")

# %% [markdown]
# # Day 30 Challenge
#
# Create a program that uses a loop that asks the user what they have thought of each of the 30 days of challenges so far.
#
# For each day, prompt the user to answer a question and restate it in a full sentence that is center aligned underneath the heading.
#
# ## Example
# ```
# 30 Days Down
#
# Day 1:
# Amazing
#
#             You thought Day 1 was amazing.
# Day 2:
# so good that I bought the David plushie
#
#               You thought Day 2 was so good...
# ```
#
# ### Instructions
# 1. Create an input statement for the user to express what they thought of that day.
# 2. Print using an f-string.
# 3. Think about what symbol you need for center alignment. How many spaces should you move your statement?
# 4. Think about the length of the heading. Maybe that's how many spaces you would need to center align the text.

# %%
print("30 Days Down - What did you think?")
print()
for i in range(1, 31):
  thought = input(f"Day {i}:\n")
  print()
  myText = f"You thought Day {i} was"
  print(f"{myText:^35}")
  print(f"{thought:^35}")
  print()

# %% [markdown]
# # Day 31 Challenge
#
# Create a classic user interface using string manipulation.
#
# Create these two user interfaces (below) using everything you know about extensions to print statements and f-strings.
#
# The second one is a bit more tricky as it involves alignment.
#
# There are no input statements. This is all about using print and variables in interesting ways. However, you may want to create a subroutine to make the color changing easier (like you did on Day 29).
#
# ### Instructions
# 1. Create a subroutine to define your colors. It can be very similar to the subroutine you used on Day 29.
# 2. Assign variables to the title, text, and words like "prev", "next", "username", etc. to make it easier to align the text.
# 3. You will need f-strings anytime you include a variable and text alignment and a string together.

# %%
def colorChange(color):
    colors = {
        "red": "\033[31m",
        "white": "\033[0m",
        "blue": "\033[34m",
        "yellow": "\033[33m",
        "green": "\033[32m",
        "purple": "\033[35m"
    }
    return colors.get(color, "\033[0m")

# Title with colors
title = f"{colorChange('red')}={colorChange('white')}={colorChange('blue')}= {colorChange('yellow')}Music App {colorChange('blue')}={colorChange('white')}={colorChange('red')}="

# Print the title centered
print(f"{title:^35}")

# Song information
print(f"🔥▶️\t{colorChange('white')}Radio Gaga")
print(f"\t{colorChange('yellow')}Queen")

# Navigation options
prev = "prev"
next = "next"
pause = "pause"

print(f"{colorChange('white')}{prev:<35}")
print(f"{colorChange('green')}{next:^35}")
print(f"{colorChange('purple')}{pause:>35}")

print()

# Welcome message
print(f"{colorChange('white')}{'WELCOME TO':^35}")
print(f"{colorChange('blue')}{'--  ARMBOOK  --':^35}")
print(f"{colorChange('yellow')}{'Definitely not a rip off':>35}")
print(f"{colorChange('yellow')}{'a certain other social':>35}")
print(f"{colorChange('yellow')}{'networking site':>35}")
print(f"{colorChange('red')}{'Honest.':^35}")

# User input
username = input(f"{colorChange('white')}{'Username: ':^35}")
password = input(f"{colorChange('white')}{'Password: ':^35}")

# %% [markdown]
# # Day 32 Challenge
#
# 1. Create a list that stores greetings in different languages. Start with the language you speak.
# 2. Then, go on the internet to find other greetings in other languages. Here is a list of greetings to get you started: [How to Say Hello in 10 Different Languages](https://www.babbel.com/en/magazine/how-to-say-hello-in-10-different-languages).
# 3. Import random library. Generate a random number between 0 and maximum number of items in your list.
# 4. At random, when the user clicks run, print one of the greetings.
# 5. Use an f-string.
#
#
# ## Instructions
#
# 1. Start with importing your library.
# 2. Add your greetings as your list.
# 3. Remember how you used random.randint to generate random numbers? Try that again here. (Don't forget to assign a variable to this).
# 4. Remember your first greeting is index 0.
# 5. print a random greeting.
# 6. You will only need four lines of code to make this project run!

# %%
import random

# List of greetings in different languages
greetings = [
    "Hello",        # English
    "Hola",         # Spanish
    "Bonjour",      # French
    "Hallo",        # German
    "Ciao",         # Italian
    "こんにちは",    # Japanese
    "안녕하세요",    # Korean
    "你好",         # Chinese
    "Привет",       # Russian
    "Olá",          # Portuguese
    "Merhaba",      # Turkish
    "مرحبا",        # Arabic
    "नमस्ते",         # Hindi
    "สวัสดี",         # Thai
    "Xin chào",     # Vietnamese
    "Sawubona",     # Zulu
    "Hej",          # Swedish
    "Ahoj",         # Czech
    "Selam",        # Albanian
    "Kamusta"       # Filipino
]

# Generate a random index
random_index = random.randint(0, len(greetings) - 1)

# Print a random greeting
print(f"Random Greeting: {greetings[random_index]}")

# %% [markdown]
# # Day 33 Challenge
#
# Create your own to do list manager. (This can be super useful!)
#
# ## Instructions
#
# 1. Ask the user whether they want to view, add, or edit their to do list.
# 2. If they want to view it, print it out in a nice way (Hint: subroutine).
# 3. If they choose to add an item to the to do list, allow them to type in the item and then add it to the bottom of the list.
# 4. If they want to edit the to do list, ask them which item they completed, and remove it from the list.
# 5. Don't worry about duplicates! The first item you put in the list should be the first item you remove.
# 6. Add a title, some color, alignment to the text, or emojis. Show off your skills!
#
# ## Example
# ```
# To Do List Manager:
# Do you want to view, add, or edit your to do list?
# view
#
# Record video for day 34
# ```
#
# # Hints
# 1. Import libraries first. What libraries will allow you to clear your code and pause it?
# 2. Remember, your list name needs to come before any subroutines or lists.
# 3. Create a subroutine very similar to the one we looked at in the common errors section.
# 4. Add a while True loop with if statements that allow the user to add, edit, or view their to do list.
# 5. Also, remember what we did to fix the second common error related to removing an item that is not in the to do list. (a nested if statement)
# 6. End with pausing and clearing your code.

# %%
import os
import time

# Initialize the to do list
toDoList = []

def printList():
    print("\nTo Do List:")
    if not toDoList:
        print("Your to do list is empty.")
    else:
        for index, item in enumerate(toDoList, start=1):
            print(f"{index}. {item}")
    print()

while True:
    os.system('cls' if os.name == 'nt' else 'clear')
    menu = input("ToDoList Manager\n\nDo you want to view, add, edit, or exit the todo list?\n").lower()
    
    if menu == "view":
        printList()
    elif menu == "add":
        item = input("What do you want to add?\n")
        toDoList.append(item)
        print(f"'{item}' has been added to your to do list.")
    elif menu == "edit":
        printList()
        try:
            item_number = int(input("Enter the number of the item you want to remove:\n"))
            if 1 <= item_number <= len(toDoList):
                removed_item = toDoList.pop(item_number - 1)
                print(f"'{removed_item}' has been removed from your to do list.")
            else:
                print("Invalid item number.")
        except ValueError:
            print("Please enter a valid number.")
    elif menu == "exit":
        print("Exiting ToDoList Manager.")
        break
    else:
        print("Invalid action. Please choose 'view', 'add', 'edit', or 'exit'.")
    
    time.sleep(2)

# %% [markdown]
# # Day 34 Challenge
# Let's extend this program and build option 4: "Get SPAMMING".
#
# 1. Print out the first 10 email addresses with a custom email sent to each of those people.
# 2. Print one email at a time, pause, and then clear the screen before the next email is printed.
#
# # Example:
# ```
# Dear john@test.com
# It has come to our attention that you're missing out on the amazing Replit 100 days of code. We insist you do it right away. If you don't we will pass on your email address to every spammer we've ever encountered and also sign you up to the My Little Pony newsletter, because that's neat. We might just do that anyway.
# Love and hugs,
# Ian Spammington III
# ```
#
# #Hints
#
# 1. Use the same libraries, list, and subroutine we just created.
# 2. Create a second subroutine relating to spam. In the for loop, we want to spam everyone. What would the range look like?
# 3. Write the email copy that will get sent to the email addresses.
# 4. Finish with the same while loop we created, but add option 4 (spamming). Make sure you only include 10 emails.
# 5. Don't forget to pause and clear the screen each time.

# %%
import os
import time

# Initialize the list of emails
listOfEmail = []

def prettyPrint():
    os.system('cls' if os.name == 'nt' else 'clear')
    print("List of Emails")
    print()
    if not listOfEmail:
        print("Your email list is empty.")
    else:
        for index, email in enumerate(listOfEmail, start=1):
            print(f"{index}: {email}")
    time.sleep12)

def spam(max_emails):
    for i in range(min(max_emails, len(listOfEmail))):
        print(f"""Email {i+1}

Dear {listOfEmail[i]},
It has come to our attention that you're missing out on the amazing Replit 100 days of code. We insist you do it right away. If you don't we will pass on your email address to every spammer we've ever encountered and also sign you up to the My Little Pony newsletter, because that's neat. We might just do that anyway.

Love and hugs,

Ian Spammington III""")
        time.sleep(1)
        os.system('cls' if os.name == 'nt' else 'clear')

# Print the initial title once
os.system('cls' if os.name == 'nt' else 'clear')
print("SPAMMER Inc.")

while True:
    menu = input("1: Add email\n2: Remove email\n3: Show emails\n4: Get SPAMMING\n5: Exit\n> ").lower()
    
    if menu == "1":
        email = input("Email > ")
        listOfEmail.append(email)
    elif menu == "2":
        email = input("Email > ")
        if email in listOfEmail:
            listOfEmail.remove(email)
    elif menu == "3":
        prettyPrint()
    elif menu == "4":
        spam(10)
    elif menu == "5":
        print("Exiting SPAMMER Inc.")
        break
    else:
        print("Invalid option. Please choose '1', '2', '3', '4', or '5'.")
    
    time.sleep(1)
    os.system('cls' if os.name == 'nt' else 'clear')

# %% [markdown]
# # Day 35 Challenge
#
# Build a really cool to do list manager. (I know we did this before...hold on!)
#
# We are going to upgrade the last to do list manager we created:
#
# ## Requirements
#
# 1. Create a menu where the user can view, add, edit, or remove an item.
# 2. The user should be able to edit the text of an item on the list too.
# 3. Don't allow the user to add duplicates.
# 4. Double check with the user they want to remove an item from the list before it is actually removed. (Is this the item they really want to remove?)
# 5. Give the user the option to completely erase the to do list. (You should be able to do this in one line of code!)
#
# ## Example
# ```
# To Do List Manager:
#
# Do you want to view, add, edit, or remove an item from the to do list?
# view
#
# record the video for day 36
#
# Do you want to view, add, edit, or remove an item from the to do list?
# remove
#
# What do you want to remove?
# record the video for day 36
#
# Are you sure you want to remove this?
# yes
# ```
#
# # Hints
#
# 1. You should be able to use all the code from Day 33 to get started. The biggest additions will be related to the menu options for edit and remove.
# 2. Use a nested if statement to verify if the user wants to remove something.

# %%
import os
import time

# Initialize the to do list
toDoList = []

def printList():
    print("\nTo Do List:")
    if not toDoList:
        print("Your to do list is empty.")
    else:
        for index, item in enumerate(toDoList, start=1):
            print(f"{index}. {item}")
    print()

while True:
    os.system('cls' if os.name == 'nt' else 'clear')
    menu = input("ToDoList Manager\n\nDo you want to view, add, edit, remove, erase (the whole list), or exit the todo list?\n").lower()
    
    if menu == "view":
        printList()
    elif menu == "add":
        item = input("What do you want to add?\n")
        if item not in toDoList:
            toDoList.append(item)
            print(f"'{item}' has been added to your to do list.")
        else:
            print(f"'{item}' is already in your to do list.")
    elif menu == "edit":
        printList()
        try:
            item_number = int(input("Enter the number of the item you want to edit:\n"))
            if 1 <= item_number <= len(toDoList):
                new_item = input("Enter the new text for the item:\n")
                toDoList[item_number - 1] = new_item
                print(f"Item {item_number} has been updated to '{new_item}'.")
            else:
                print("Invalid item number.")
        except ValueError:
            print("Please enter a valid number.")
    elif menu == "remove":
        printList()
        try:
            item_number = int(input("Enter the number of the item you want to remove:\n"))
            if 1 <= item_number <= len(toDoList):
                item_to_remove = toDoList[item_number - 1]
                confirm = input(f"Are you sure you want to remove '{item_to_remove}'? (yes/no)\n").lower()
                if confirm == "yes":
                    toDoList.pop(item_number - 1)
                    print(f"'{item_to_remove}' has been removed from your to do list.")
                else:
                    print("Item not removed.")
            else:
                print("Invalid item number.")
        except ValueError:
            print("Please enter a valid number.")
    elif menu == "erase":
        toDoList.clear()
        print("Your to do list has been erased.")
    elif menu == "exit":
        print("Exiting ToDoList Manager.")
        break
    else:
        print("Invalid action. Please choose 'view', 'add', 'edit', 'remove', 'erase', or 'exit'.")
    
    time.sleep(1)

# %% [markdown]
# String Manipulation
#
# .lower = all letters are lower case
#
# .upper = all letters are upper case
#
# .title = capital letter for the first letter of every word
#
# .capitalize = capital letter for the first letter of only the first word
#
# Adding .strip() removes any spaces on either side of the word.

# %% [markdown]
# # Day 36 Challenge
#
# ### Instructions:
# 1. Create a list of people's names. Ask for first and last name (surname) separately.
# 2. Strip any extra spaces.
# 3. Store names in a capitalized version.
# 4. Create a new string using an `f-string` that combines the tidied-up version of the first name and the tidied-up version of the last name.
# 5. Add those new versions to a list.
# 6. Do not allow duplicates.
# 7. Each time you add a new name, print out the full list.
#
# ### 💡 Hints:
# - Start with your list name. Remember, it should be blank.
# - Create your subroutine.
# - Next, create a `while True` loop, including input for first and last name.
# - Use `.capitalize()` to ensure the first letter is capitalized.
# - Get rid of spaces before you capitalize with `.strip()`.
# - Use an `if` statement to eliminate duplicates.

# %%
import os
import time

# Initialize the rolodex
rolodex = []

def printList():
    os.system('cls' if os.name == 'nt' else 'clear')
    print("\nRolodex:")
    if not rolodex:
        print("Your rolodex is empty.")
    else:
        for name in rolodex:
            print(name)
    print()

while True:
    os.system('cls' if os.name == 'nt' else 'clear')
    print("Rolodex Manager")
    choice = input("Choose an option: 1: Add a name 2: Exit").strip()

    if choice == "1":
        firstName = input("First Name: ").strip().capitalize()
        lastName = input("Last Name: ").strip().capitalize()
        name = f"{firstName} {lastName}"
        if name not in rolodex:
            rolodex.append(name)
            print(f"'{name}' has been added to your rolodex.")
        else:
            print("ERROR: Duplicate name")
        printList()
        time.sleep(2)  # Pause for 2 seconds to allow the user to see the result
    elif choice == "2":
        print("Exiting Rolodex Manager.")
        break
    else:
        print("Invalid option. Please choose '1' or '2'.")
        time.sleep(1)  # Pause for 2 seconds to allow the user to see the error message
# Out:
# Rolodex Manager
# 'Vane Ariza' has been added to your rolodex.
#
# Rolodex:
# Vane Ariza
#
# Rolodex Manager
# Exiting Rolodex Manager.

# %% [markdown]
# # String Slicing
#
# 1. To slice a single character from a string, you use the index of that character in square brackets [] just like you'd use with a list! Gasp!
#
# ```
# myString = "Hello there my friend."
# print(myString[0])
#
# # This code outputs the 'H' from 'Hello'
# ```
#
# 2. To slice more than one character, you use two indices (yes that is the plural form of 'index'): the start character and one after your desired end character.
#
# ```
# myString = "Hello there my friend."
# print(myString[6:11])
#
# # This code outputs 'there'.
# ```
#
# 3. Leaving the first index blank defaults to 'start from index 0'.
#
# ```
# myString = "Hello there my friend."
# print(myString[:11])
#
# # This code outputs 'Hello there'.
# ```
#
# 4. Leaving the last index blank defaults to 'go to the end'.
#
# ```
# myString = "Hello there my friend."
# print(myString[12:])
# # This code outputs 'my friend.'.
# ```

# %% [markdown]
# 6. Adding a third argument to the square brackets [] specifies the gap left between characters.
#
# Try to print every other character in the word 'hello':
# ```
# myString = "Hello there my friend."
# print(myString[0:6:2])
#
# # This code outputs 'Hlo' (every second character from 'Hello').
# ```
# Can you print every third character in the whole string?
# ```
# myString = "Hello there my friend."
# print(myString[::3])
#
# # This code outputs 'Hltrmfe!' (every third character from the whole string).
# ```
# 7. Using a negative number in the third argument can be super useful. It starts the slice from the end of the string instead of the beginning.
#
# Can you print the string backwards?!
# ```
# myString = "Hello there my friend."
# print(myString[::-1])
#
# #This code reverses the string, outputting '.dneirf ym ereht olleH'
# ```

# %% [markdown]
# # Split
#
# 1. Split lets us split a string into a list of individual words by separating it at the space characters.
# ```
# myString = "Hello there my friend."
# print(myString.split())
#
# #This code outputs ['Hello', 'there', 'my', 'friend.']
# ```

# %% [markdown]
# # Day 37 Challenge: Star Wars Name Generator
#
# This program will generate your **Star Wars Name**.
#
# ### Instructions:
# 1. Ask the user to input their first and last names.
# 2. Slice the first 3 letters of the first name.
# 3. Slice the first 3 letters of the last name (surname).
# 4. Join them together. Change the case to make it look good - think `f-strings` or `.upper()`/`.lower()`. This will be the user's Star Wars first name.
# 5. Ask the user for their mother's maiden name and the city where they were born.
#    - Maiden name refers to the last name their mother had before getting married.
#    - If unknown, make up a last name.
# 6. Combine the first 2 letters of the maiden name with the last 3 letters of the city to create the user's Star Wars last name. Use `f-strings` and `.upper()`/`.lower()`.
# 7. Finally, print the full Star Wars name as part of a sentence.
#
# ### 🥳 Extra Points:
# - Use a single `input()` command and the `split()` function to get all the inputs at once.
#
# ### Example:
# ```plaintext
# 🌟Star Wars Name Generator🌟
# Input your first name > David
# Input your lastname > Morgan
# Input your mother's maiden name > Jones
# Input the city where you were born > Cardiff
#
# Your Star Wars name is Davmor Joiff
# ```
#
# ### Hints
# 1. To get charaters from the beginning of a string, leave the first argument blank. ex: [:3] gets the first 3 characters.
# 2. To get charaters from the end of a string, make the first argument a negative number for how many charaters to get. Leave the last argument blank. ex: [-5:] gets the last 5 characters.
# 3. fString formatting uses .title for first character capitalization and .lower for all lower case.
# 4. Use fStrings to join the sliced characters to a new variable as you get the correct characters from each string.
# 5. For extra points, get the user to input all info at once separated by spaces.

# %%
print("STAR WARS NAME GENERATOR")

all = input("Enter your first name, last name, Mum's maiden name and the city you were born in").split()

first = all[0].strip()
last = all[1].strip()
maiden = all[2].strip()
city = all[3].strip()

name = f"{first[:3].title()}{last[:3].lower()} {maiden[:2].title()}{city[-3:].lower()}"

print(f"Your Star Wars name is {name}")
# Out:
# STAR WARS NAME GENERATOR
# Your Star Wars name is Miqmol Evada

# %% [markdown]
# # Strings and Loops
#
# Now that we know that strings are basically lists in disguise, we can start to harness the power of loops with them.
#
# ### String Slicing Using a For Loop
#
# 👉 This for loop creates a variable called `letter`. It is used to store each character in the string as the loop goes through it, starting at the first character.
#
# The `print()` statement uses the `letter` variable and will output the string one character at a time (just like a list).
#
# ```python
# myString = "Day 38"
# for letter in myString:
#   print(letter)
#
# # This code outputs:
# #D
# #a
# #y
#
# #3
# #8
# # this is a comment in the code, the computer will ignore it
# ```
#
# This means that we can do certain things to certain characters inside the loop.
#
# ### if statement inside the loop
# 👉 This code will examine the lower case version of each character. If it's an 'a', the computer will change the font color to yellow before printing.
#
# Outside of the loop, the last line sets the font color back to default for the next character in the loop.
# ```python
# myString = "Day 38"
# for letter in myString:
#   if letter.lower() == "a":
#     print('\033[33m', end='') #yellow
#   print(letter)
#   print('\033[0m', end='') #back to default
#
# # This code outputs (with a yellow 'a'):
# #D
# #a
# #y
#
# #3
# #8
# ```
#
# ### Using a list to specify search items
# 👉 If the letters are in my list called vowels, they will print out in yellow.
#
# I changed the print statement on the last line back to the default color with the ending system.
# ```python
# vowels = ["a","e","i","o","u"]
#
# myString = "Will my vowels now be yellow?"
# for letter in myString:
#
#   if letter.lower() in vowels:
#     print('\033[33m', end='') #yellow
#
#   print(letter, end="")
#   print('\033[0m', end='') #back to default
#   ```

# %% [markdown]
# # 🌈 Day 38 Challenge
#
# ## Code the Rainbow!
#
# ### Steps:
# 1. Ask the user to input any sentence (string).
# 2. Now we'll rainbow-ize (nope, me neither) it.
# 3. As soon as the string contains an `'r'`, every letter from that point on should be **red**.
# 4. When the computer encounters a `'b'`, `'g'`, `'p'`, or `'y'`, the output should change to:
#    - **Blue** for `'b'`
#    - **Green** for `'g'`
#    - **Purple** for `'p'`
#    - **Yellow** for `'y'`
# 5. Loop through the string and output it (so the color continues through the loop).
# 6. The output should change color every time it encounters a new `'r'`, `'g'`, `'b'`, `'p'`, or `'y'`.
#
# 🎉 **Extra Points:** Reset the output color back to default every time there's a space.
#
# ### Example:
# ```plaintext
# What sentence do you want rainbow-ising?
# Become one with the rainbow my young rainbowan
# ```
#
# ### Hints
# 1. You can use a lot of your code from Day 31 to get started.
# 2. Use an ```if... elif... else``` structure to check for key letters.
# 3. Use the ```print("\033[31m", end="")``` to change the font color.
# 4. Try implementing the color change as a subroutine.

# %%
def colorChange(color):
  if color=="r":
    print("\033[31m", end="")
  elif color==" ":
    print("\033[0m", end="")
  elif color=="b":
    print("\033[34m", end="")
  elif color=="y":
    print("\033[33m", end="")
  elif color == "g":
    print("\033[32m", end="")
  elif color == "p":
    print("\033[35m", end="")

sentence = input("What sentence do you want rainbow-izing?: ")
for letter in sentence:
  colorChange(letter.lower())
  print(letter, end="")
print()
# Out:
# cuando tu vas, yo vengo de allí

# %%
#To color every letter

def colorChange(color):
    colors = {
        "r": "\033[31m",  # Red
        " ": "\033[0m",   # Reset
        "b": "\033[34m",  # Blue
        "y": "\033[33m",  # Yellow
        "g": "\033[32m",  # Green
        "p": "\033[35m"   # Purple
    }
    print(colors.get(color, "\033[0m"), end="")

def cycleColors(index):
    color_codes = ["\033[31m", "\033[34m", "\033[33m", "\033[32m", "\033[35m"]
    return color_codes[index % len(color_codes)]

sentence = input("What sentence do you want rainbow-izing?: ")
for index, letter in enumerate(sentence):
    print(cycleColors(index), end="")
    print(letter, end="")
print("\033[0m")  # Reset color at the end
# Out:
# cuando tu vas, yo vengo de allí

# %% [markdown]
# # 🎯 Day 39 Challenge
#
# ## Hangman Game
#
# ### Steps:
# 1. Prompt the user to type in a letter.
# 2. Check if the letter is in the word.
# 3. If it is, output the word with all blanks apart from the letter(s) they've already guessed.
# 4. Keep a running list of the letters they've used.
# 5. Count how many times they've picked a letter that isn't in the word:
#    - If it's more than 6, they lose.
# 6. Output a **"win"** message if they reveal all the letters.
#
# 🎨 **Extra Points:** Use ASCII art to draw the hangman as the player makes incorrect guesses.
#
# ### Example:
# 🌟 **Hangman** 🌟
#
# ```plaintext
# Choose a letter: i
# Nope, not in there.
# 5 left.
#
# Choose a letter: a
# Correct!
# _a_
#
# Choose a letter: s
# Correct!
# s_a_
#
# Choose a letter: u
# Correct!
# sua_
#
# # Repeat until...
# # If user wins:
# You won with 5 lives left.
#
# # If user loses:
# You lost!
# ```
# ### Hints
# 1. Check if a letter is in the string: ```if inputLetter in string```.
# 2. Try using underscores to show blanks to let the user know how many more letters there are to guess.
# 3. Keep track of letters used. Try adding each letter chosen to a new list, then checking this list for each subsequent choice.
# 4. Check out our [100 Days of Code forum](https://replit.com/community-hub) for help.

# %%
import random
import os
import time

listOfWords = ["apple", "orange", "grapes", "pear"]
letterPicked = []
lives = 6

word = random.choice(listOfWords)

# Display the number of letters in the word from the beginning
print("The word has", len(word), "letters.")
print(" ".join("_" * len(word)))

while True:
    time.sleep(1)
    os.system('cls' if os.name == 'nt' else 'clear')
    letter = input("Choose a letter: ").lower()
    
    if letter in letterPicked:
        print("You've tried that before")
        continue
    
    letterPicked.append(letter)
    
    if letter in word:
        print("You found a letter")
    else:
        print("Nope, not in there")
        lives -= 1
    
    allLetters = True
    print()
    for i in word:
        if i in letterPicked:
            print(i, end=" ")
        else:
            print("_", end=" ")
            allLetters = False
    print()
    
    # Display the letters that have already been used
    print("Letters used:", " ".join(letterPicked))
    
    if allLetters:
        print(f"You won with {lives} lives left!")
        break

    if lives <= 0:
        print(f"You ran out of lives! The answer was {word}")
        break
    else:
        print(f"Only {lives} lives left")
# Out:
# The word has 6 letters.
# _ _ _ _ _ _
# You found a letter
#
# __a___
# Letters used: a
# Only 6 lives left
# You found a letter
#
# __ap__
# Letters used: a p
# Only 6 lives left
# You've tried that before
# Nope, not in there
#
# __ap__
# Letters used: a p l
# Only 5 lives left
# You found a letter
#
# __ape_
# Letters used: a p l e
# Only 5 lives left
# You found a letter
#
# g_ape_
# Letters used: a p l e g
# Only 5 lives left
# You found a letter
#
# grape_
# Letters used: a p l e g r
# Only 5 lives left
# You found a letter
#
# grapes
# Letters used: a p l e g r s
# You won with 5 lives left!
